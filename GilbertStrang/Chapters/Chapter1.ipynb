# %% [markdown]
# # Introduction to vectors

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# ### Learning objectives

# %% [markdown]
# ## 1.1 Addition and Substraction of vectors

# %% [markdown]
# ### Concept
#
# Vectors can be defined as arrows having a direction and distance. it can also be defined as a point or an object. it is a set of verticle coordinates. We add two vectors to get a new vector in space.
#
# 1. 1 vector with a scalar extends or shrinks a line
# 2. 2 vectors can cover a whole plain
# 3. 3 vectors can cover a $\mathbb{R}^3$

# %% [markdown]
# ### Python Implementation
